# %%
import glob 
import pandas as pd

filenames = sorted(glob.glob('./namiki_dailylog/log/*_log.csv'))

for f in filenames:
    print(f)
    df = pd.read_csv(f)
    
    oneday = df.loc[df['hourtocalve'] > -25] 

    x = oneday['hourtocalve']
    y = oneday['stepdifcc']
    plt.plot(x,y)
    plt.fill_between(x, min(oneday['stepdifcc']), max(oneday['stepdifcc']), where= oneday['hourofday'] > 18, facecolor='green', alpha=0.1)
    plt.fill_between(x, min(oneday['stepdifcc']), max(oneday['stepdifcc']), where=oneday['hourtocalve'] >= -4, facecolor='pink', alpha=0.1)
    plt.ylabel('no.of steps')
    plt.xlabel('hour to calving')
    plt.legend(loc=2)
    
    plt.show()

    #df1.to_csv(f'{f[:-4]}_log.csv')
# Out:
# ./namiki_dailylog/log/10_34296_2019-07-05~2019-07-10_log.csv
# ./namiki_dailylog/log/10_61172_2019-08-13~2019-08-24_log.csv
# ./namiki_dailylog/log/10_89396_2019-08-29~2019-09-03_log.csv
# ./namiki_dailylog/log/13_49098_2019-07-05~2019-07-12_log.csv
# ./namiki_dailylog/log/15_74802_2019-08-21~2019-08-23_log.csv
# ./namiki_dailylog/log/17_11153_2019-08-13~2019-08-20_log.csv
# ./namiki_dailylog/log/1_7928_2019-09-10~2019-09-12_log.csv
# ./namiki_dailylog/log/1_85092_2019-07-05~2019-08-09_log.csv
# ./namiki_dailylog/log/21_31968_2019-09-10~2019-09-17_log.csv
# ./namiki_dailylog/log/21_6826_2019-08-13~2019-08-29_log.csv
# ./namiki_dailylog/log/21_9588_2019-07-17~2019-07-19_log.csv
# ./namiki_dailylog/log/22_75167_2019-07-17~2019-07-23_log.csv
# ./namiki_dailylog/log/22_9451_2019-07-05~2019-07-09_log.csv
# ./namiki_dailylog/log/23_24750_2019-08-13~2019-08-26_log.csv
# ./namiki_dailylog/log/24_75599_2019-07-17~2019-07-28_log.csv
# ...
